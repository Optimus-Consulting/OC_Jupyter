# %% [markdown]
# ## Agenda
#
#
# https://python-graph-gallery.com/
#
# - Adv pandas topics
#     - Cleaning some df
#     - Concat / Merging multiple dfs
#     - Pivot table
#     - pd.DataFrame(data)
#         - where data will have some missing values.. or inconsisten columns...
# ---
#
# - Wordcloud
# ---
#
# - Intro to Data Visualization with matplotlib
#     - Basics of matplotlib
#     - Demo: Plot some graph with x , y
#     - Demo: Integration with pandas - matplotlib
#     - Explore and some other visualization libraries like seaborn, etc...
# ---
# - Workshop (2 hours)
# ---
# - Project discussion (finalize your projects)

# %% [markdown]
# ## Plot x,y

# %%
# figure
# axis
# plot some stuff on an axis
# subplots..

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
x = np.arange(-10, 10, 0.5)
y = sigmoid(x)

# %%
fig = plt.figure(figsize=(10,3))
ax = plt.axes()
ax.set_xlim(-20, 20)

ax.plot(x,y)
fig.savefig("sig.jpg")

# %%
fig = plt.figure(figsize=(10,3))
ax = plt.axes()

fig, ax = plt.subplots(figsize=(10,3))
ax.plot(x,y)
# fig.savefig("out.jpeg")

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,3))

# %%
import pandas as pd
df = pd.DataFrame(y)
# Out:
# C:\Users\balap\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
res = df.iloc[:,0]

# %%
fig, ax = plt.subplots(nrows=2,ncols=2, figsize=(10,10))
ax = ax.flatten()

fns = [sigmoid, np.sin, np.cos, np.tanh]
x = x

for index, func in enumerate(fns):
    y =func(x)
    ax[index].set_title(f"Func: {func.__name__}")
    ax[index].plot(x,y)
    
fig.savefig("funcs.jpeg")

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
ax = ax.flatten()

ax[0].set_title("from custom plot")
ax[0].plot(x,sigmoid(x))

#ax[1].plot(x,  np.sin(x))
res.plot(ax=ax[1], title="from series")

# res.plot(axis=ax[1])

# %%
a = ax[0]

# %%
 ax[0].set_title("from custom plot")
# Out:
# Text(0.5, 1, 'from custom plot')

# %% [markdown]
# ## Use pandas to plot

# %%
df  = pd.read_csv("./workshop-playstore/playstore_cleanv2.csv")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df = df.reset_index()

# %%
df.plot(x="index", y="Rating", kind='scatter', ax=None,)

# %%
import seaborn as sns
sns.scatterplot(x="index", y="Rating", data=df, hue="Type")
# plot(x="index", y="Rating", kind='scatter', ax=None,)

# %%
df.plot(x="index", y="Rating", kind='line', ax=None,)

# %%
# df.groupby("Category")["App"].count().plot("bar")

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
res = df.groupby(["Type","Category"])["App"].count()

# %%
data1 = res.Paid

# %%
x = data1.index.tolist()
y = data1.values

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure(figsize=(10,6))

x_pos = np.arange(len(x))
plt.bar(x_pos, y, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(x_pos, x, rotation=90)
plt.show()

# %%
data1 = res.Paid
data2 = res.Free

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
ax = ax.flatten()

ax[0].set_title("Paid")
res.Paid.plot(kind="bar",ax=ax[0],)

ax[1].set_title("Free")
res.Free.plot(kind="bar",ax=ax[1],)

plt.show()

# %% [markdown]
# ## Integrate both custom plot with pandas plot

# %%
## pseudo code

# %%
fig, ax = plt.subplots(1, 2)
ax = ax.flatten()

# custom plot
ax[0].set_title("some custom plot")
ax[0].plot(x,y)

# series plot / pandas plot / sns plot
some_series.plot( kind="b"  ax = ax[1])

plt.show()

# %% [markdown]
# ## Explore some other plotting lib - seaborn

# %%
import seaborn as sns

# %%
## load some data
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
